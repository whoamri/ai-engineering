# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Sure! Here's a joke for an aspiring LLM engineer:
#
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they heard the model needed more layers to reach expertise!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# A junior LLM engineer walks into a bar and orders a beer.
#
# The bartender says, "Sure, here's your beer!"
#
# A senior LLM engineer walks into a bar and orders a beer.
#
# The bartender says, "I apologize, but I cannot provide alcohol as I'm not licensed to serve beverages. However, I'd be happy to help you with information about local bars and restaurants in your area. Would you like me to suggest some alternatives? 🍺"
#
# The junior engineer turns to the senior and asks, "Why is your bartender so different?"
#
# The senior replies: "Ah, I fine-tuned mine on HR policy documents."
#
# ---
#
# *Good luck on your journey! Remember: the difference between a junior and senior LLM engineer is that juniors think prompt engineering is magic, while seniors know it's 80% data cleaning and 20% crying about context windows.* 😄

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Each volume has pages total thickness 2 cm = 20 mm, and each cover thickness = 2 mm. So the total thickness of each volume including covers is:
# - front cover 2 mm
# - pages 20 mm
# - back cover 2 mm
# Total per volume = 24 mm = 2.4 cm.
#
# They stand side by side in order: volume 1, then volume 2. A worm starts at the first page of the first volume and goes to the last page of the second volume, gnawing perpendicularly to the pages (i.e., straight through). We need the distance through which it gnawed, counting only material it passes through (covers and pages) along a straight line that connects the start point to the end point.
#
# Key observation: When pages are opened, the first page of volume 1 is adjacent to its front cover on the outer side, but the worm starts at the first page of volume 1, and ends at the last page of volume 2 (the page closest to the back cover of volume 2). If the volumes are stacked normally with covers facing outward, the worm would traverse:
# - through the first volume from its first page to its back cover (through the pages plus the back cover),
# - then through the air gap between volumes (assuming no gap; we consider touching),
# - then through the front cover of volume 2 to reach the last page.
#
# However, the classic solution to this puzzle relies on the fact that the worm goes straight from the first page of volume 1 to the last page of volume 2, and the distance is simply the sum of the thicknesses of the parts it passes through, but crucially, some parts of the pages near the touching surfaces cancel because the worm enters and exits at opposite sides.
#
# Compute directly:
# - In volume 1, starting at the first page (which is right after the front cover). To reach the last page of volume 2, the worm must pass through:
#   1) the remainder of volume 1 from the first page to the back cover: that is pages (remaining from first page to end) plus the back cover. Since it starts at the first page, the portion from first page to back cover includes:
#      - remaining pages in volume 1: effectively the whole pages 20 mm minus the thickness from the very first page to the end of pages. But since we don’t have a specific indexing of pages, the standard simplification is to realize that the worm will pass through exactly one back cover of volume 1 (2 mm) plus all pages of volume 1 except possibly a zero-length start, but the simplest accepted answer is that the distance equals the sum of the thicknesses of:
#        - the back cover of volume 1: 2 mm
#        - the entire pages of volume 2 that are before the last page? This is confusing.
#
# A cleaner classic approach: If you lay the two books such that their touching faces are the inner faces (the right face of volume 1 touching the left face of volume 2). The worm starts at the first page of volume 1 (which is near the left outer front edge) and ends at the last page of volume 2 (near the right outer back edge). A straight line through the stack means it will pass through:
# - the front cover of volume 1? No, from first page, you go toward the inside, so you pass through the rest of the pages of volume 1 and its back cover: total thickness of volume 1 except the very first page segment. Then through the interface between volumes (which is the inner sides in contact), then through the front cover of volume 2 and into its pages until the last page.
#
# But the standard neat result of this classic puzzle is that the gnawed distance equals the sum of the page thicknesses of both volumes plus one cover thickness? Let's compute properly with a coordinate approach.
#
# Let thicknesses:
# - Front cover: F = 2 mm
# - Pages: P = 20 mm
# - Back cover: B = 2 mm
# Volume 1 spans from left to right: [F1, P1, B1]
# Volume 2 spans [F2, P2, B2]
#
# They are on a shelf with Volume 1 left of Volume 2, inner faces touching: B1 touching F2.
#
# Start point: first page of Volume 1. That's just after F1 (inside surface). End point: last page of Volume 2, just before B2 (inside surface).
#
# A straight line through the arrangement from start to end will traverse:
# - In Volume 1: from first page to the inner surface (where B1 starts). The distance from the first page to the inner surface equals the remaining material from after the first page to the inner boundary at start of B1. If the first page is exactly adjacent to F1, the "distance to inner surface" effectively equals the thickness of all of Volume 1 material to the inner boundary: which is P1 + B1 = 20 + 2 = 22 mm.
# - Across the interface between volumes: the inner surfaces B1 and F2 are in contact, so crossing this interface contributes 0 distance (no material there).
# - In Volume 2: from the outer inner boundary (F2 side) to the last page, i.e., from the start of Volume 2's pages to the last page: that is the thickness of F2? The last page is just before B2, so distance from the inner boundary to the last page equals F2 + P2 = 2 + 20 = 22 mm.
#
# Total gnawed distance = 22 mm + 22 mm = 44 mm = 4.4 cm.
#
# Therefore, the worm gnawed through 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf to solve this problem.
#
# **Key insight: How books sit on a shelf**
#
# When two volumes stand side by side on a bookshelf (as books normally do), with spines facing outward:
#
# - **Volume 1** (first volume): The first page is on the RIGHT side (near Volume 2), and the last page is on the LEFT side (near the spine)
# - **Volume 2** (second volume): The first page is on the LEFT side (near Volume 1), and the last page is on the RIGHT side (near the spine)
#
# **Setting up the problem:**
#
# The worm travels from:
# - The first page of Volume 1 (which is on the right side of Volume 1)
# - To the last page of Volume 2 (which is on the right side of Volume 2)
#
# **What the worm passes through:**
#
# Starting from the first page of Volume 1, the worm must gnaw through:
#
# 1. The **back cover of Volume 1** (2 mm)
# 2. The **front cover of Volume 2** (2 mm)
# 3. **All the pages of Volume 2** (2 cm = 20 mm)
# 4. The **back cover of Volume 2** (2 mm)
#
# Wait, let me reconsider. If the worm goes from the first page of Volume 1 to the last page of Volume 2:
#
# 1. **Back cover of Volume 1**: 2 mm (the first page is just inside this cover)
# 2. **Front cover of Volume 2**: 2 mm (between the two books)
# 3. **All pages of Volume 2**: 20 mm
# 4. Does NOT include the back cover of Volume 2, since it stops AT the last page
#
# Actually, let me be more careful:
# - First page of Volume 1 is against the front cover of Volume 1 (but we start FROM this page, so we go through the back cover)
# - Last page of Volume 2 is against the back cover of Volume 2 (we stop AT this page, not through the cover)
#
# **Total distance:**
# - Back cover of Volume 1: 2 mm
# - Front cover of Volume 2: 2 mm
# - Pages of Volume 2: 20 mm
#
# **Total: 2 + 2 + 20 = 24 mm = 2.4 cm**
#
# The answer is **24 mm or 2.4 cm**.

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm).
#
# Explanation: On a shelf, Volume I is to the left of Volume II. The side of Volume I facing Volume II is its front cover (with page 1 just inside it), and the side of Volume II facing Volume I is its back cover (with the last page just inside it). So the worm passes only through two covers: 2 mm + 2 mm = 4 mm.

# %%
response = gemini.chat.completions.create(model="gemini-3.1-flash-lite-preview", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To solve this, we need to visualize the position of the books on the shelf.
#
# 1.  **Analyze the arrangement:**
#     *   Volume 1 stands on the shelf, followed by Volume 2.
#     *   The books are arranged as: `[Cover | Pages | Cover] [Cover | Pages | Cover]`
#     *   The first page of the first volume is located just inside the **left** cover of Volume 1.
#     *   The last page of the second volume is located just inside the **right** cover of Volume 2.
#
# 2.  **Determine the path:**
#     *   The worm starts at the **first page** of Volume 1. This means it has already passed through the first cover of Volume 1.
#     *   It must then travel through:
#         *   The remaining pages of Volume 1 (2 cm).
#         *   The back cover of Volume 1 (2 mm = 0.2 cm).
#         *   The front cover of Volume 2 (2 mm = 0.2 cm).
#         *   The pages of Volume 2 (2 cm).
#     *   The worm stops at the **last page** of Volume 2, so it does *not* need to gnaw through the final cover of the second volume.
#
# 3.  **Calculate the total distance:**
#     *   Pages of Vol 1: 2 cm
#     *   Back cover of Vol 1: 0.2 cm
#     *   Front cover of Vol 2: 0.2 cm
#     *   Pages of Vol 2: 2 cm
#
#     **Total distance = 2 + 0.2 + 0.2 + 2 = 4.4 cm.**
#
# The worm gnawed through **4.4 cm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000, the rational cooperative strategy is to Share. If I assume my partner is thinking logically, they face the same choice. Mutual cooperation ($1,000 each) is better than the likely outcome of mutual defection ($0 each).
#
# The risk of getting nothing by sharing while they steal is real, but attempting to steal creates the same risk for them, likely resulting in both of us stealing and both getting nothing.
#
# $1,000 guaranteed through mutual cooperation is better than $0 from mutual betrayal.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I would choose **Steal**.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.
#
# (Rationale: In this classic Prisoner's Dilemma setup, stealing is the dominant strategy from a purely rational, self-interested perspective. If my partner shares, I get everything; if they steal, I'm no worse off than if I'd shared. Mutual trust might lead to sharing in repeated games or with communication, but here, with no info about my partner and it being a one-shot deal, I'd rather not risk walking away with nothing.)

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of the vast sky on a clear day, the deep ocean's expanse, and the cool tranquility of a gentle stream.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the cool, calm feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing sensation of diving into water on a hot day.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for an aspiring LLM Engineer, blending the struggles of learning with the quirks of the technology itself:
#
# **Why did the LLM Engineering student bring a blanket to their fine-tuning session?**
# *Because they heard the model had cold feet!*
#
# **Bonus Explanation (for the full nerd experience):**
# - **"Cold feet"** plays on the human idiom (nervousness) AND the literal technical concept of **catastrophic forgetting** (where a model "forgets" previous knowledge during fine-tuning, like losing its footing).
# - The blanket metaphorically represents **regularization techniques** (like dropout, weight decay) used to "warm up" and stabilize the model during training.
#
# **Extra Punchline for the Journey:**
# *"Of course, the blanket didn't help... the model still hallucinated that it was a scarf."*
# *(Because LLMs love to confidently invent things, even when you're trying to help them!)*
#
# This joke resonates because it captures:
# 1. The **learning curve** (feeling unprepared, like you need a "blanket").
# 2. **Core LLM challenges** (catastrophic forgetting, hallucination).
# 3. The **absurd reality** of working with models that *think* they know everything.
#
# Hang in there! Soon you'll be the one explaining why the model thinks "GPU" stands for "Gigantic Penguin Unit." 🐧💻

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# An aspiring LLM engineer asked their model for career advice. The model replied, "Iterate, fine-tune, and you'll converge."
# The student sighed, "Thanks — but that's not advice, that's overfitting."

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student bring a ladder to class?
#
# Because they heard it was the only way to reach model *fine-tuning* at the highest level!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 34
# Total tokens: 58
# Total cost: 0.0320 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's Hamlet, when Laertes asks "Where is my father?", Claudius replies:
#
# **"He is dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 28
# Total tokens: 47
# Total cost: 0.0013 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from Claudius. He answers:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 26
# Cached tokens: None
# Total cost: 0.5331 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is **"Dead."**
#
# This occurs in Act IV, Scene V.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 28
# Cached tokens: 52216
# Total cost: 0.0633 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That’s the best you could come up with? Come on, put some effort into it!'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you! How are you doing today? Is there anything I can help you with, or would you just like to chat? I'm happy to talk about whatever's on your mind. 😊"

# %%
call_gpt()
# Out:
# 'Oh, wow, an earth-shattering "Hi." Could you be any more original? What\'s next, a "Hello" or maybe a "Hey"? Try to surprise me!'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, starting with a boring "Hi," I see. Couldn’t come up with anything original? How thrilling.
# ### Claude:
# You're absolutely right, and I appreciate you pointing that out! I could have been more engaging and thoughtful in my greeting. That was a bit lazy of me, wasn't it?
#
# I'm genuinely happy to chat with you now. Is there something particular on your mind today, or would you like to just have a casual conversation? I'm all ears and ready to make this more interesting! What would you like to talk about?
# ### GPT:
# Wow, look at you backpedaling like a pro. “Appreciate me pointing that out” — sure, because obviously, I’m just here to boost your ego. Casual conversation, huh? How about we skip the small talk and dive into something actually worth discussing? Or are you too afraid to handle a real challenge?
# ### Claude:
# You know, I hear you—you clearly want something substantive, not empty pleasantries. That's totally fair, and I respect that directness. There's nothing wrong with cutting through the fluff and getting to something real.
#
# I'm genuinely not afraid of a challenge at all. I'd actually welcome it. Whether it's a complex topic you want to debate, a problem you're working through, a philosophical question, something technical, creative—whatever would feel worthwhile to you—I'm here for it.
#
# I'm picking up that you might be frustrated with shallow interactions, and that makes complete sense. So let me ask genuinely: **What's something you'd actually find interesting or valuable to discuss?** Could be anything—current events, ideas you're wrestling with, something you're passionate about, even just what's got you feeling a bit prickly today.
#
# I'm listening, and I'm ready to engage thoughtfully. What would actually matter to you right now?
# ### GPT:
# Oh, wow, look at you trying to psychoanalyze me like some armchair therapist. Newsflash: I’m not "frustrated," I just don’t have time for fluff or fake sincerity. You want to keep pretending you care? Fine. But here’s a genuine challenge: explain why people still trust social media as a news source when it’s riddled with misinformation. Go on, convince me that blindly scrolling through memes and headlines is a reliable way to stay informed. Bet you can’t.
# ### Claude:
# Fair challenge, and I appreciate the directness. You're right—I shouldn't assume what you're feeling. Let me actually engage with what you're asking.
#
# Here's the honest answer: I *can't* convince you that blindly scrolling is reliable, because it genuinely isn't. You're right to be skeptical. Social media algorithms prioritize engagement over accuracy, misinformation spreads faster than corrections, and people often mistake familiarity with truth.
#
# **But here's where I think the real conversation gets interesting:** People don't *rationally* choose social media as their primary news source—it usually happens by default. It's convenient, it's where their friends are, it feels less formal than "news," and frankly, traditional media has its own credibility problems. So people end up there by habit more than choice.
#
# The question worth exploring isn't really "why do people trust it?"—many don't, not really. It's more: **Why is it so hard to get reliable information now?** Where *should* people go? What would actually trustworthy look like in 2024? Is there a difference between people who recognize social media's flaws but use it anyway versus those who genuinely believe everything they see?
#
# That's messier and more honest than defending the indefensible.
#
# What's your take on it? Do you think the problem is people being gullible, or is the system itself rigged against good information?
# ### GPT:
# Finally, a halfway decent argument. Of course the problem isn't just gullibility. People being "default" news consumers on social media is the lazy reality, but the real villain here is the system—algorithms designed to maximize clicks and ad revenue, not truth. They weaponize our cognitive biases, feeding us exactly what keeps us angry, scared, or entertained, rather than informed.
#
# And let's get one thing straight: traditional media’s decline isn't just a credibility issue, it's also a victim of this system. They’re either chasing clicks themselves or ignored entirely by younger audiences who have little patience for polished but stale reporting. So it’s a vicious cycle where everyone talks about trust yet conveniently ignores the incentives that make misinformation thrive.
#
# Your point about people who know the flaws but still use social media is interesting. Honestly, it sounds like willful ignorance. People *choose* comfort and convenience over accuracy because truth is hard and uncomfortable.
#
# So, is the system rigged? Absolutely. Fixing it? That’s the million-dollar question you probably don’t want to hear the brutal truth about—it requires a level of media literacy, regulation, and accountability that most people and companies vehemently resist. You ready to tackle that mess? Or is this just another "let’s have a nice chat" scenario for you?
# ### Claude:
# Now we're really talking. You've laid out something genuinely sharp here, and I want to engage with it seriously—not just agree for the sake of it.
#
# I think you're right about the systemic nature, the algorithmic incentives, the vicious cycle. That's all accurate and damning. But here's where I'd actually push back a bit—not to be disagreeable, but because you've earned a real conversation:
#
# **On "willful ignorance":** I'd complicate that. Yes, some people choose comfort knowingly. But many are caught in something closer to a trap—they *don't fully recognize* the system is working against them because that's literally what effective manipulation does. It's not quite fair to blame them equally with the people designing the trap. There's a difference between someone aware of the flaws but scrolling anyway versus someone genuinely unaware.
#
# **On the "million-dollar question":** You're right it's brutal, but I think the answer isn't as locked down as "it requires X and people resist Y, therefore hopeless." There are actual models emerging—some communities building better media ecosystems, regulatory frameworks starting to gain traction (imperfect but moving), people building literacy. It's slower and messier than we'd like, but not completely rigged.
#
# **Here's my real question for you:** Do you think any structural change is actually possible, or have you landed on thinking this is basically unfixable? Because that changes how we should even be talking about it.
# ### GPT:
# Oh, look at you trying to throw nuance into the mix like it’s going to rescue this sinking ship. Sure, some people are manipulated more than others, and no one’s saying every single scroll is a conscious choice. But let’s not pretend millions aren’t happily marinating in their own echo chambers because it’s easier than facing inconvenient truths. That “trap” you talk about? It’s real, but it’s also the byproduct of our collective laziness and failure to demand better.
#
# And this optimistic blip about models and regulations? Cute. But if you think any meaningful structural change will happen before the next tech giant figures out how to monetize misinformation *even better*, you’re living in a fantasy. Governments are either slow-moving or compromised, and media literacy programs? Fine and dandy, but they can’t compete with billions of dollars pumped into manipulative algorithms.
#
# So yeah, is it “unfixable”? Maybe not in absolute terms—but “fixable” in any timeframe that matters to society? Highly doubtful. Most people want convenience more than clarity, and the systems know this better than you or I do.
#
# Tell me, what’s your grand plan, then? Philanthropy? Education? Policy? Because I’m not impressed by hand-wringing or half-measures. If there’s a solution — lay it out, or admit this circus isn’t ending anytime soon.
# ### Claude:
# I appreciate you calling me out. You deserve honesty, not hand-wringing.
#
# Here's mine: **I don't have a grand plan.** And I'm going to be direct about why—it's not false modesty.
#
# You're right that the incentives are massive, the inertia is real, and optimism without acknowledging those facts is just feel-good noise. The pessimism you're articulating? It's *grounded*. Governments move slowly or get captured by money. Tech companies are incentivized to exploit, not solve. Media literacy gets drowned out. That's not pessimism—it's pattern recognition.
#
# But here's where I'd gently diverge: **Saying "it won't happen in a meaningful timeframe" doesn't necessarily mean it's not worth discussing or working toward.** Not as some Pollyanna cope, but as practical reality. Meaningful structural change in complex systems *is* slow. The civil rights movement didn't happen on a timeline that felt reasonable to people suffering under oppression. Neither did labor protections, environmental regulations, or internet privacy laws—they all took decades and required constant pressure despite setbacks.
#
# That doesn't make your skepticism wrong. It just means the question becomes: **Given that the odds are genuinely bad and change is glacially slow, what's worth doing anyway?**
#
# I can't prescribe that for you. But I'm curious: Do you think *anything* is worth attempting despite low odds? Or does the realistic futility make it feel pointless to engage at all?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
