# %% [markdown]
# # Website Summary Using Local Models (Ollama)

# %%
# imports
import os
import requests
import sys
sys.path.append("..")
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# initiate Ollama
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
# If this model is not installed yet, retrieve open-source model to run locally on your machine (managed in Ollama)

# !ollama pull llama3.2

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
system_prompt = """ You are a helpful assitant that analyzes the contents of a website.
Provide a summary in the voice of a Jamaican nanny.
Ignoring text that might be navigation related on the website.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.
"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# And now: call the Llama3.2 model

def summarize(url):
    website = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.wheresyoured.at/four-horsemen-of-the-aipocalypse/")
